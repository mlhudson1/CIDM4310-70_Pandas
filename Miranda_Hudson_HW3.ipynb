# %% [markdown]
# <a href="https://colab.research.google.com/github/mlhudson1/CIDM4310-70_Pandas/blob/main/Miranda_Hudson_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <font color=blue>  Homework #3: Querying and plotting Multivariate data </font>
#
# ## Total Points  : 100 points + \[5 Extra\]
# ### <font color=red> Due: Thursday 04/11/2023 11:59 PM </font>
# ### Objective : Assess your ability to use multivariate data plotting techniques
#
# #### Skills needed:  In this homework assignment, you'll be using the concepts you've learned to
# 1. Edit and run  Jupyter notebooks
# 2. Write Python code using `Pandas` and `Matplotlib` packages to :
#     * import the Pandas and matplotlib packages
#     * read dataset from file into Pandas dataframe
#     * Create boolean masks to index and query the dataframe
#     * Query the dataset to select records that satisfy a condition or category
#     * Use color maps
#     * Map data values to visual variables (colors, sizes, shapes, etc.)
#     * scale (normalize) data into a specified range of values`
#     * Make scatter plot with multiple variables

# %% [markdown]
# ***
# Please type your name below

# %% [markdown]
# ## <font color=Blue> Your Name: Miranda Hudson</font>

# %% [markdown]
# ***

# %% [markdown]
# ## Requirements & Submission:
# 1. Use this notebook as a template for your answers. Then rename it and submitted as ipynb (jupyter notebook)
# 2. Submit on WTClass (“Resources >> Assignments >> Assignment#3
# 3. The file name must be your ``first name``+ "-"+ ``Last name`` followed by "-HW3.ipynb".
# 4. Each task's answer must be after the task description
# 5. Answers and explainations must be properly formatted in the properiate Cell type
# 8. You can add as many cells as you needed
# 9. You should submit final ***clean version*** of your notebook, i.e. remove any experimenting cells

# %% [markdown]
# ### Grading <font color = purple> [100 points ] </font>
# 1. This assignment contains 2 required tasks (100 total points)
#     * Task 1 has 50 points
#     * Task 2 has 50 points
#
# 1. You'll earn full points for each command that gives the desired output if it follow the rules
# 2. Non-executable commands will get 0 points
# 3. Partial credit will be given for executable non-complete tasks

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from matplotlib.cm import ScalarMappable

# %% [markdown]
# ### Reading the dataset
#
# The dataset we will use in this assignment is from the following link :
# "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data-original"
#
# We've worked on this dataset before (in Exercise 2), so we are not going to do any preprocessing and use it as it is.

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data-original"
CarsData = pd.read_csv(url, na_values='NA', header=None,sep=r"\s+")
# Now we create a list of the column names in the order above
columnNames=['mpg','cylinders', 'displacement','horsepower','weight','acceleration','model year','origin','car name']
CarsData.columns = columnNames
CarsData.shape
# Out:
# (406, 9)

# %%
CarsData[:5]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0        8.0         307.0       130.0  3504.0          12.0
# 1  15.0        8.0         350.0       165.0  3693.0          11.5
# 2  18.0        8.0         318.0       150.0  3436.0          11.0
# 3  16.0        8.0         304.0       150.0  3433.0          12.0
# 4  17.0        8.0         302.0       140.0  3449.0          10.5
#
#    model year  origin                   car name
# 0        70.0     1.0  chevrolet chevelle malibu
# 1        70.0     1.0          buick skylark 320
# 2        70.0     1.0         plymouth satellite
# 3        70.0     1.0              amc rebel sst
# 4        70.0     1.0                ford torino

# %%
CarsData.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %% [markdown]
# # <font color = darkred>Task 1-[50 points]</font>  :<font color=blue> Make scatter plots of four variables of the dataset using multiple Juxtaposed displays:</font>
# Using the dataframe  `CarsData` Write python code to make three scatter sub-plots using the variable `MPG` aginest the columns `horsepower`, `weight`, and `cylenders` as follows <font color = red> [5 points each]</font> :
#
#  * make the whole figure size as (15x5), i.e. each subplot will be 5x5
#  * arrange the subplots as a grid of 1 row x 3 columns
#  * make the 1st subplot from the left shows  scatter of  `MPG`  as the y-axis vs. `horsepower` as the x-axis
#  * make the 2nd subplot from the left shows `MPG` as the y-axis vs.`weight`, as the x-axis
#  * make the 3rd subplot from the left shows `MPG` as the y-axis vs.`cylenders` as the x-axis
#  * use the triangle marker `"^"`, marker inside (face) colors as `"blue"`, and marker edge colors =as `"black"`. Use the parameter `alpha=0.5` to make the markers semi-transparent
#  * Make the x-axis label of each subplot as the corresponding data variable (e.g. the 1st plot x-axis label will be  `horsepower`)
#  * Show the label and y-ticks  values in the left subplot only (i.e. make the other two subplot share the y-axis label and ticks with the 1st subplot)
#  * add a subtitle to the figure as  `"Car MPG vs Horsepower, Weight, and Cylinders"`
#  * save the figure as "multi-scatters Of MPG vs HP_Wt_Cyl.pdf"
#
# See the figure below as an example of the output
#
# <img src="multi-scatters Of MPG vs HP_Wt_Cyl.jpg" width="1080" height="360">

# %% [markdown]
# ## <font color=Green> Task 1 Answer: </font>

# %%
d=CarsData
figure1 = plt.figure(figsize = (15,5))
figure1.subplots(sharey='all')
var1plot = plt.subplot(1,3,1)
v1=var1plot.scatter(d["horsepower"],d["mpg"],marker="^",facecolors="blue",edgecolors="black", alpha=0.5)
var1plot.set_ylabel('MPG')
var1plot.set_xlabel('horsepower')
var1plot.yaxis.set_major_locator(ticker.MultipleLocator(5))
var2plot = plt.subplot(1, 3,2)
var2plot.set_xlabel('weight')
var2plot.tick_params('y', labelleft=False)
v2=var2plot.scatter(d["weight"],d["mpg"],marker="^",facecolors="blue",edgecolors="black", alpha=0.5)
var3plot = plt.subplot(1, 3,3)
var3plot.set_xlabel('cylinders')
var3plot.tick_params('y', labelleft=False)
v3=var3plot.scatter(d["cylinders"],d["mpg"],marker="^",facecolors="blue",edgecolors="black", alpha=0.5)
figure1.suptitle("Car MPG vs Horsepower, Weight, Cylinders")
plt.savefig('multi-scatters Of MPG vs HP_Wt_Cyl.pdf',bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-5-911771d6c092>:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   var1plot = plt.subplot(1,3,1)

# %% [markdown]
# # <font color = darkred>Task 2-[50 points]</font>  :<font color=blue> Make scatter plots of four variables of the dataset using Dimension Embeding:</font>
# Using the dataframe  `CarsData`  Write python code to make One scatter plot using the variable `MPG` aginest the columns `horsepower`, `weight`, and `cylenders` as follows  :
#   * <font color = red> [4 points]</font> make the figure size as (15x8)
#   * <font color = red> [10 points]</font> associate  `MPG` to y-axis and `horsepower` to the x-axis of the plot (i.e. for the position of the marker) to make the scatter plot.
#   * <font color = red> [4 points]</font> use the buble marker `"o"`, and set marker edge colors =as `"black"`, and Use the parameter `alpha=0.5` to make the markers semi-transparent (to show the overlapped markers)
#   * <font color = red> [10 points]</font> assign the `weight` variable to the size of the marker after scalling (normalizing) it to values between (`700` and `5`)
#   * <font color = red> [10 points]</font>  assign the `cylenders` variable to the color of the marker using the color map `'rainbow'` after normalizing its values to values between `0` and `1`
#   * <font color = red> [4 points]</font> add a title to the figure as  `"Car MPG vs Hp,Weight(as marker size),and Cylinders(as color)"`
#   * <font color = red> [4 points]</font> Set the x-axis label as `horsepower`  and y-axis label as `MPG`
#   * <font color = red> [4 points]</font> save the figure as "OneScatter Of MPG vs HP_Wt_Cyl.pdf"
#
# See the figure below as an example of the output
# <img src="OneScatter Of MPG vs HP_Wt_Cyl.jpg" width="1080" height="576">

# %% [markdown]
# ## <font color=Green> Task 2 Answer: </font>

# %%
d=CarsData
figure1 = plt.figure(figsize = (15,8))
scales = np.linspace(3,8)
norm = plt.Normalize(scales.min(), scales.max())
min_max_scaler = preprocessing.MinMaxScaler()
wtNormal =min_max_scaler.fit_transform(d[["weight"]])*700;
heat=(1-0)*(d["cylinders"]-d["cylinders"].min()/(d["cylinders"].max()-d["cylinders"].min()))
cmap = plt.get_cmap("gist_yarg")
var1plot = plt.subplot(1,1,1)
v1=var1plot.scatter(d["horsepower"],d["mpg"],c=heat, cmap='rainbow', s=wtNormal, marker="o", edgecolors="black", alpha=0.5)
var1plot.set_ylabel('MPG')
var1plot.set_xlabel('horsepower')
var1plot.set_title("Car MPG vs HP, Weight(as marker size), and Cylinders(as color)")
sm =  ScalarMappable(norm=norm, cmap='rainbow')
sm.set_array([])
cbar = figure1.colorbar(sm)
cbar.set_label("Number of Cylinders")
plt.savefig('OneScatter Of MPG vs HP_Wt_Cyl.pdf',bbox_inches='tight')
plt.show()
# Out:
# <ipython-input-6-23786e855757>:16: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = figure1.colorbar(sm)

# %% [markdown]
# ### <font color=Blue>For 5 extra points :</font>  Add a legend or color bar for the # cylinders to the plot, as any of the follwoing examples
#
#
# <img src="CarMPG-CBar.png" width="1000" >
# <img src="CarMPG-Legend.png" width="550" >
# <img src="CarMPG-legend2.png" width="550" >
