# %% [markdown]
# # Activity 5.01 - Creating a multi-index from columns

# %% [markdown]
# 1. For this activity, all you will need is the pandas library. Load it into the first cell of the notebook.

# %%
import pandas as pd

# %% [markdown]
# 2. Read in the mushroom.csv data from the Datasets directory and list the first five rows using .head().

# %%
mr_data= pd.read_csv('Chapter5-Datasets/mushroom.csv')
mr_data.head(5)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %% [markdown]
# 3. You will see the class column and many visible attributes. List all the columns to see what else there is to work with.

# %%
mr_data.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %% [markdown]
# 4. In addition to class, you see population and habitat, which are not visible attributes. You decide to create a multi-index using class, population, and habitat.

# %%
mr_index = pd.MultiIndex.from_frame(mr_data[['class','population','habitat']])

# %% [markdown]
# 5. Now, drop the columns that are in the index and set the DataFrame index to the multi-index. Make sure that you drop the existing default index.

# %%
mr_data.drop(columns=['class','population','habitat'], inplace=True)
mr_data.set_index(mr_index, drop=True, inplace=True)
mr_data
# Out:
#                          cap-shape cap-surface cap-color bruises odor  \
# class population habitat
# p     s          u               x           s         n       t    p
# e     n          g               x           s         y       t    a
#                  m               b           s         w       t    l
# p     s          u               x           y         w       t    p
# e     a          g               x           s         g       f    n
# ...                            ...         ...       ...     ...  ...
#       c          l               k           s         n       f    n
#       v          l               x           s         n       f    n
#       c          l               f           s         n       f    n
# p     v          l               k           y         n       f    y
# e     c          l               x           s         n       f    n
#
#                          gill-attachment gill-spacing gill-size gill-color  \
# class population habitat
# p     s          u                     f            c         n          k
# e     n          g                     f            c         b          k
#                  m                     f            c         b          n
# p     s          u                     f            c         n          n
# e     a          g                     f            w         b          k
# ...                                  ...          ...       ...        ...
#       c          l                     a            c         b          y
#       v          l                     a            c         b          y
#       c          l                     a            c         b          n
# p     v          l                     f            c         n          b
# e     c          l                     a            c         b          y
#
#                          stalk-shape stalk-root stalk-surface-above-ring  \
# class population habitat
# p     s          u                 e          e                        s
# e     n          g                 e          c                        s
#                  m                 e          c                        s
# p     s          u                 e          e                        s
# e     a          g                 t          e                        s
# ...                              ...        ...                      ...
#       c          l                 e          ?                        s
#       v          l                 e          ?                        s
#       c          l                 e          ?                        s
# p     v          l                 t          ?                        s
# e     c          l                 e          ?                        s
#
#                          stalk-surface-below-ring stalk-color-above-ring  \
# class population habitat
# p     s          u                              s                      w
# e     n          g                              s                      w
#                  m                              s                      w
# p     s          u                              s                      w
# e     a          g                              s                      w
# ...                                           ...                    ...
#       c          l                              s                      o
#       v          l                              s                      o
#       c          l                              s                      o
# p     v          l                              k                      w
# e     c          l                              s                      o
#
#                          stalk-color-below-ring veil-type veil-color  \
# class population habitat
# p     s          u                            w         p          w
# e     n          g                            w         p          w
#                  m                            w         p          w
# p     s          u                            w         p          w
# e     a          g                            w         p          w
# ...                                         ...       ...        ...
#       c          l                            o         p          o
#       v          l                            o         p          n
#       c          l                            o         p          o
# p     v          l                            w         p          w
# e     c          l                            o         p          o
#
#                          ring-number ring-type spore-print-color
# class population habitat
# p     s          u                 o         p                 k
# e     n          g                 o         p                 n
#                  m                 o         p                 n
# p     s          u                 o         p                 k
# e     a          g                 o         e                 n
# ...                              ...       ...               ...
#       c          l                 o         p                 b
#       v          l                 o         p                 b
#       c          l                 o         p                 b
# p     v          l                 o         e                 w
# e     c          l                 o         p                 o
#
# [8124 rows x 20 columns]

# %% [markdown]
# 6. Use the .loc[] notation you learned and list the data about the edible mushrooms.

# %%
mr_data.loc['e',:]
# Out:
#                    cap-shape cap-surface cap-color bruises odor  \
# population habitat
# n          g               x           s         y       t    a
#            m               b           s         w       t    l
# a          g               x           s         g       f    n
# n          g               x           y         y       t    a
#            m               b           s         w       t    a
# ...                      ...         ...       ...     ...  ...
# v          l               x           s         n       f    n
# c          l               k           s         n       f    n
# v          l               x           s         n       f    n
# c          l               f           s         n       f    n
#            l               x           s         n       f    n
#
#                    gill-attachment gill-spacing gill-size gill-color  \
# population habitat
# n          g                     f            c         b          k
#            m                     f            c         b          n
# a          g                     f            w         b          k
# n          g                     f            c         b          n
#            m                     f            c         b          g
# ...                            ...          ...       ...        ...
# v          l                     a            c         b          y
# c          l                     a            c         b          y
# v          l                     a            c         b          y
# c          l                     a            c         b          n
#            l                     a            c         b          y
#
#                    stalk-shape stalk-root stalk-surface-above-ring  \
# population habitat
# n          g                 e          c                        s
#            m                 e          c                        s
# a          g                 t          e                        s
# n          g                 e          c                        s
#            m                 e          c                        s
# ...                        ...        ...                      ...
# v          l                 e          ?                        s
# c          l                 e          ?                        s
# v          l                 e          ?                        s
# c          l                 e          ?                        s
#            l                 e          ?                        s
#
#                    stalk-surface-below-ring stalk-color-above-ring  \
# population habitat
# n          g                              s                      w
#            m                              s                      w
# a          g                              s                      w
# n          g                              s                      w
#            m                              s                      w
# ...                                     ...                    ...
# v          l                              s                      o
# c          l                              s                      o
# v          l                              s                      o
# c          l                              s                      o
#            l                              s                      o
#
#                    stalk-color-below-ring veil-type veil-color ring-number  \
# population habitat
# n          g                            w         p          w           o
#            m                            w         p          w           o
# a          g                            w         p          w           o
# n          g                            w         p          w           o
#            m                            w         p          w           o
# ...                                   ...       ...        ...         ...
# v          l                            o         p          o           o
# c          l                            o         p          o           o
# v          l                            o         p          n           o
# c          l                            o         p          o           o
#            l                            o         p          o           o
#
#                    ring-type spore-print-color
# population habitat
# n          g               p                 n
#            m               p                 n
# a          g               e                 n
# n          g               p                 k
#            m               p                 k
# ...                      ...               ...
# v          l               p                 o
# c          l               p                 b
# v          l               p                 b
# c          l               p                 b
#            l               p                 o
#
# [4208 rows x 20 columns]
